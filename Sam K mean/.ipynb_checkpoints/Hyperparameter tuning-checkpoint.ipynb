# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
sb.set() # set the default Seaborn style for graphics
pd.options.mode.chained_assignment = None
scaler = MinMaxScaler()

# %%
imported_data = pd.read_csv("../miami_housing.csv") #import fresh data  
print(imported_data.columns)
scaled = scaler.fit_transform(imported_data)
scaled = pd.DataFrame(scaled).reset_index(drop=True)
dataset = pd.DataFrame(scaled, columns = ['LATITUDE', 'LONGITUDE', 'PARCELNO', 'SALE_PRC', 'LND_SQFOOT', 'TOT_LVG_AREA', 'SPEC_FEAT_VAL', 'RAIL_DIST', 'OCEAN_DIST', 'WATER_DIST', 'CNTR_DIST', 'SUBCNTR_DI', 'HWY_DIST', 'age', 'avno60plus', 'month_sold', 'structure_quality'])
#dataset
# Out:
# Index(['LATITUDE', 'LONGITUDE', 'PARCELNO', 'SALE_PRC', 'LND_SQFOOT',
#        'TOT_LVG_AREA', 'SPEC_FEAT_VAL', 'RAIL_DIST', 'OCEAN_DIST',
#        'WATER_DIST', 'CNTR_DIST', 'SUBCNTR_DI', 'HWY_DIST', 'age',
#        'avno60plus', 'month_sold', 'structure_quality'],
#       dtype='object')
#        LATITUDE  LONGITUDE  PARCELNO  SALE_PRC  LND_SQFOOT  TOT_LVG_AREA  \
# 0           NaN        NaN       NaN       NaN         NaN           NaN
# 1           NaN        NaN       NaN       NaN         NaN           NaN
# 2           NaN        NaN       NaN       NaN         NaN           NaN
# 3           NaN        NaN       NaN       NaN         NaN           NaN
# 4           NaN        NaN       NaN       NaN         NaN           NaN
# ...         ...        ...       ...       ...         ...           ...
# 13927       NaN        NaN       NaN       NaN         NaN           NaN
# 13928       NaN        NaN       NaN       NaN         NaN           NaN
# 13929       NaN        NaN       NaN       NaN         NaN           NaN
# 13930       NaN        NaN       NaN       NaN         NaN           NaN
# 13931       NaN        NaN       NaN       NaN         NaN           NaN
#
#        SPEC_FEAT_VAL  RAIL_DIST  OCEAN_DIST  WATER_DIST  CNTR_DIST  \
# 0                NaN        NaN         NaN         NaN        NaN
# 1                NaN        NaN         NaN         NaN        NaN
# 2                NaN        NaN         NaN         NaN        NaN
# 3                NaN        NaN         NaN         NaN        NaN
# 4                NaN        NaN         NaN         NaN        NaN
# ...              ...        ...         ...         ...        ...
# 13927            NaN        NaN         NaN         NaN        NaN
# 13928            NaN        NaN         NaN         NaN        NaN
# 13929            NaN        NaN         NaN         NaN        NaN
# 13930            NaN        NaN         NaN         NaN        NaN
# 13931            NaN        NaN         NaN         NaN        NaN
#
#        SUBCNTR_DI  HWY_DIST  age  avno60plus  month_sold  structure_quality
# 0             NaN       NaN  NaN         NaN         NaN                NaN
# 1             NaN       NaN  NaN         NaN         NaN                NaN
# 2             NaN       NaN  NaN         NaN         NaN                NaN
# 3             NaN       NaN  NaN         NaN         NaN                NaN
# 4             NaN       NaN  NaN         NaN         NaN                NaN
# ...           ...       ...  ...         ...         ...                ...
# 13927         NaN       NaN  NaN         NaN         NaN                NaN
# 13928         NaN       NaN  NaN         NaN         NaN                NaN
# 13929         NaN       NaN  NaN         NaN         NaN                NaN
# 13930         NaN       NaN  NaN         NaN         NaN                NaN
# 13931         NaN       NaN  NaN         NaN         NaN                NaN
#
# [13932 rows x 17 columns]

# %%
def three_Feature_clustering(varname):
    dataset = pd.read_csv("../miami_housing.csv") #import fresh data  
    dataset = scaler.fit_transform(dataset)
    X = dataset[['LATITUDE', 'LONGITUDE', 'PARCELNO', varname]]
    k_means = KMeans(n_clusters=5, init='random', random_state=4)
    X['clusters'] = k_means.fit_predict(X[['LATITUDE', 'LONGITUDE', varname]])
    X = X[['PARCELNO', 'clusters']]
    dataset = dataset.merge(X, left_on="PARCELNO", right_on="PARCELNO")
    plt.figure(figsize=(16, 6))
    sb.scatterplot(data=dataset, x="LONGITUDE", y="LATITUDE", hue="clusters", palette="deep")
    plt.figure(figsize=(8,5))
    sb.boxplot(x='clusters',y='SALE_PRC',data=dataset, palette='rainbow')
    string = "Price based on cluster with variable " +str(varname)
    plt.title(string)

# %%
three_Feature_clustering("OCEAN_DIST")
# Out:
# <ipython-input-32-b501dda66438>:4: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   X = dataset[['LATITUDE', 'LONGITUDE', 'PARCELNO', varname]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-24872c2e3178> in <module>
# ----> 1 three_Feature_clustering("OCEAN_DIST")
#
# <ipython-input-32-b501dda66438> in three_Feature_clustering(varname)
#       2     dataset = pd.read_csv("../miami_housing.csv") #import fresh data
#       3     dataset = scaler.fit_transform(dataset)
# ----> 4     X = dataset[['LATITUDE', 'LONGITUDE', 'PARCELNO', varname]]
#       5     k_means = KMeans(n_clusters=5, init='random', random_state=4)
#       6     X['clusters'] = k_means.fit_predict(X[['LATITUDE', 'LONGITUDE', varname]])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
