# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from collections import Counter
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
mmScaler = MinMaxScaler()
sScaler = StandardScaler()
sns.set()

# %%
df = pd.read_csv('miami-housing.csv')
# print the dataset 
df.head()
# Out:
#     LATITUDE  LONGITUDE      PARCELNO  SALE_PRC  LND_SQFOOT  TOT_LVG_AREA  \
# 0  25.891031 -80.160561  6.222800e+11    440000        9375          1753
# 1  25.891324 -80.153968  6.222800e+11    349000        9375          1715
# 2  25.891334 -80.153740  6.222800e+11    800000        9375          2276
# 3  25.891765 -80.152657  6.222800e+11    988000       12450          2058
# 4  25.891825 -80.154639  6.222800e+11    755000       12800          1684
#
#    SPEC_FEAT_VAL  RAIL_DIST  OCEAN_DIST  WATER_DIST  CNTR_DIST  SUBCNTR_DI  \
# 0              0     2815.9     12811.4       347.6    42815.3     37742.2
# 1              0     4359.1     10648.4       337.8    43504.9     37340.5
# 2          49206     4412.9     10574.1       297.1    43530.4     37328.7
# 3          10033     4585.0     10156.5         0.0    43797.5     37423.2
# 4          16681     4063.4     10836.8       326.6    43599.7     37550.8
#
#    HWY_DIST  age  avno60plus  month_sold  structure_quality
# ...

# %%
x = df[['LATITUDE','LONGITUDE']]

# %% [markdown]
# ## Here we compute k-NearestNeighbour in order to estimate the optimal epsilon

# %%
nbrs = NearestNeighbors(n_neighbors=118)
nbrs_fit = nbrs.fit(x)
neigh_dist, neigh_ind = nbrs.kneighbors(x)
sort_neigh_dist = np.sort(neigh_dist, axis=0)
k_dist = sort_neigh_dist[:, 117]
plt.figure(figsize=(16,6))
plt.plot(k_dist)
plt.axhline(y=0.06, linewidth=1, linestyle='dashed', color='k')
plt.ylabel("k-NN distance")
plt.xlabel("Sorted observations (117th NN)")
plt.show()

# %% [markdown]
# ## Here we take minPts to be 4, the optimal, according to A Density-Based Algorithm for Discovering Clusters, Ester M.

# %%
clusters = DBSCAN(eps=0.06, min_samples=4).fit(x)
x['clusters'] = clusters.labels_
plt.figure(figsize=(16,6))
p = sns.scatterplot(data=x, x="LONGITUDE", y="LATITUDE", hue=clusters.labels_, legend="full", palette="deep")
sns.move_legend(p, "upper right", bbox_to_anchor=(1.17, 1.2), title='Clusters')
plt.show()
# Out:
# C:\Users\Trevor\AppData\Local\Temp\ipykernel_21476\3459182504.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['clusters'] = clusters.labels_

# %% [markdown]
# ### Try MinMax Normalisation

# %%
df = pd.read_csv('miami-housing.csv')
x[['LATITUDE','LONGITUDE']] = mmScaler.fit_transform(x[['LATITUDE','LONGITUDE']])
nbrs = NearestNeighbors(n_neighbors=118)
nbrs_fit = nbrs.fit(x)
neigh_dist, neigh_ind = nbrs.kneighbors(x)
sort_neigh_dist = np.sort(neigh_dist, axis=0)
k_dist = sort_neigh_dist[:, 117]
plt.figure(figsize=(16,6))
plt.plot(k_dist)
plt.axhline(y=0.2, linewidth=1, linestyle='dashed', color='k')
plt.ylabel("k-NN distance")
plt.xlabel("Sorted observations (117th NN)")
plt.show()

# %%
df = pd.read_csv('miami-housing.csv')
x[['LATITUDE','LONGITUDE']] = mmScaler.fit_transform(x[['LATITUDE','LONGITUDE']])
clusters = DBSCAN(eps=0.2, min_samples=4).fit(x)
x['clusters'] = clusters.labels_
plt.figure(figsize=(16,6))
p = sns.scatterplot(data=x, x="LONGITUDE", y="LATITUDE", hue=clusters.labels_, legend="full", palette="deep")
sns.move_legend(p, "upper right", bbox_to_anchor=(1.1, 1), title='Clusters')
plt.show()

# %% [markdown]
# ### Try Standard Normalisation

# %%
df = pd.read_csv('miami-housing.csv')
x[['LATITUDE','LONGITUDE']] = sScaler.fit_transform(x[['LATITUDE','LONGITUDE']])
nbrs = NearestNeighbors(n_neighbors=118)
nbrs_fit = nbrs.fit(x)
neigh_dist, neigh_ind = nbrs.kneighbors(x)
sort_neigh_dist = np.sort(neigh_dist, axis=0)
k_dist = sort_neigh_dist[:, 117]
plt.figure(figsize=(16,6))
plt.plot(k_dist)
plt.axhline(y=0.6, linewidth=1, linestyle='dashed', color='k')
plt.ylabel("k-NN distance")
plt.xlabel("Sorted observations (117th NN)")
plt.show()

# %%
df = pd.read_csv('miami-housing.csv')
x[['LATITUDE','LONGITUDE']] = sScaler.fit_transform(x[['LATITUDE','LONGITUDE']])
clusters = DBSCAN(eps=0.6, min_samples=4).fit(x)
x['clusters'] = clusters.labels_
plt.figure(figsize=(16,6))
p = sns.scatterplot(data=x, x="LONGITUDE", y="LATITUDE", hue=clusters.labels_, legend="full", palette="deep")
sns.move_legend(p, "upper right", bbox_to_anchor=(1.1, 1), title='Clusters')
plt.show()

# %% [markdown]
# ### Try different Epsilon value

# %%
df = pd.read_csv('miami-housing.csv')
x = df[['LATITUDE','LONGITUDE']]
clusters = DBSCAN(eps=0.0085, min_samples=4).fit(x)
x['clusters'] = clusters.labels_
plt.figure(figsize=(16,6))
p = sns.scatterplot(data=x, x="LONGITUDE", y="LATITUDE", hue=clusters.labels_, legend="full", palette="deep")
sns.move_legend(p, "upper right", bbox_to_anchor=(1.1, 1), title='Clusters')
plt.show()
# Out:
# C:\Users\Trevor\AppData\Local\Temp\ipykernel_21476\1979744561.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['clusters'] = clusters.labels_

# %%
df = pd.read_csv('miami-housing.csv')
x = df[['LATITUDE','LONGITUDE']]
clusters = DBSCAN(eps=0.0085, min_samples=20).fit(x)
x['clusters'] = clusters.labels_
plt.figure(figsize=(16,6))
p = sns.scatterplot(data=x, x="LONGITUDE", y="LATITUDE", hue=clusters.labels_, legend="full", palette="deep")
sns.move_legend(p, "upper right", bbox_to_anchor=(1.1, 1), title='Clusters')
plt.show()
# Out:
# C:\Users\Trevor\AppData\Local\Temp\ipykernel_21476\1332122773.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['clusters'] = clusters.labels_

# %%
df = pd.read_csv('miami-housing.csv')
x = df[['LATITUDE','LONGITUDE']]
clusters = DBSCAN(eps=0.02, min_samples=150).fit(x)
x['clusters'] = clusters.labels_
plt.figure(figsize=(16,6))
p = sns.scatterplot(data=x, x="LONGITUDE", y="LATITUDE", hue=clusters.labels_, legend="full", palette="deep")
sns.move_legend(p, "upper right", bbox_to_anchor=(1.1, 1), title='Clusters')
plt.show()
# Out:
# C:\Users\Trevor\AppData\Local\Temp\ipykernel_21476\3619165437.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['clusters'] = clusters.labels_
